# %%
import ctypes

# %%
# !g++ -fPIC -shared -o libjacobi.so jacobi.cpp

# %%
lo = ctypes.CDLL('./libjacobi.so')

# %%
lo.OLD_main()
# Out:
# grid:
# 0.5 0.5
# 0.5 0.5
# grid:
# 8.58333 0.25
# 33.5833 8.58333
# grid:
# 16.7917 4.29167
# 37.625 16.7917
# grid:
# 18.8125 8.39583
# 41.7292 18.8125
# grid:
# 20.8646 9.40625
# 42.7396 20.8646
# grid:
# 21.3698 10.4323
# 43.7656 21.3698
# grid:
# 21.8828 10.6849
# 44.0182 21.8828
# grid:
# 22.0091 10.9414
# 44.2747 22.0091
# grid:
# 22.1374 11.0046
# 44.3379 22.1374
# grid:
# 22.1689 11.0687
# 44.402 22.1689
# grid:
# 22.201 11.0845
# 44.4178 22.201
# grid:
# 22.2089 11.1005
# 44.4338 22.2089
# grid:
# 22.2169 11.1045
# 44.4378 22.2169
# grid:
# 22.2189 11.1085
# 44.4418 22.2189
# grid:
# 22.2209 11.1094
# 44.4428 22.2209
# grid:
# 22.2214 11.1104
# 44.4438 22.2214
# grid:
# 22.2219 11.1107
# 44.444 22.2219
# grid:
# 22.222 11.1109
# 44.4443 22.222
# grid:
# 22.2221 11.111
# 44.4443 22.2221
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# ...

# %%
lo.OLD_main.restype=ctypes.POINTER(ctypes.c_double)

# %%
lo.OLD_main()
# Out:
# grid:
# 0.5 0.5
# 0.5 0.5
# grid:
# 8.58333 0.25
# 33.5833 8.58333
# grid:
# 16.7917 4.29167
# 37.625 16.7917
# grid:
# 18.8125 8.39583
# 41.7292 18.8125
# grid:
# 20.8646 9.40625
# 42.7396 20.8646
# grid:
# 21.3698 10.4323
# 43.7656 21.3698
# grid:
# 21.8828 10.6849
# 44.0182 21.8828
# grid:
# 22.0091 10.9414
# 44.2747 22.0091
# grid:
# 22.1374 11.0046
# 44.3379 22.1374
# grid:
# 22.1689 11.0687
# 44.402 22.1689
# grid:
# 22.201 11.0845
# 44.4178 22.201
# grid:
# 22.2089 11.1005
# 44.4338 22.2089
# grid:
# 22.2169 11.1045
# 44.4378 22.2169
# grid:
# 22.2189 11.1085
# 44.4418 22.2189
# grid:
# 22.2209 11.1094
# 44.4428 22.2209
# grid:
# 22.2214 11.1104
# 44.4438 22.2214
# grid:
# 22.2219 11.1107
# 44.444 22.2219
# grid:
# 22.222 11.1109
# 44.4443 22.222
# grid:
# 22.2221 11.111
# 44.4443 22.2221
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# 22.2222 11.1111
# 44.4444 22.2222
# grid:
# ...
